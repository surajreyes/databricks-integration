# %% [markdown]
# # Prerequisites

# %% [markdown]
# ## Create RDD

# %% [markdown]
# # Basic Problem Statements

# %% [markdown]
# ## Problem Statement
# > Remove the header and print first 5 records

# %% [markdown]
# ## Problem Statement
# >Count the number of elements in the RDD

# %% [markdown]
# ## Problem Statement
#  > Select 'id' and 'designation' columns

# %% [markdown]
# ## Problem Statement
# > Filter records whose designation is 'technician' and show 'id, age, designation', with count

# %% [markdown]
# ## Problem Statement
#
# > Save the results into a file

# %% [markdown]
# # Intermediate Problem Statements

# %% [markdown]
# ## Problem Statement
# > Show distinct 'designation' column

# %% [markdown]
# ## Problem Statement
#
# > Sum of salary for each 'designation'

# %% [markdown]
# ## Problem Statement
#
# > Average salary for each 'designation'

# %% [markdown]
# ## Problem Statement
# > Sort by 'designation'
